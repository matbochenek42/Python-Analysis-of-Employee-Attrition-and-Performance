# %% [markdown]
# # EDA

# %% [markdown]
# ## INTRO
#
# The goal of this file is to

# %%
# CHANGE USER_PATH

from pathlib import Path


USER_PATH = Path(r"C:\Users\Mateusz\Desktop\ZBIORCZE\TECH\ANALIZA DANYCH\Python\Projekty MB") 


df_path = USER_PATH / "Python Analysis of Employee Attrition & Performance" / "dataframe.csv"

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv(df_path)

# %%
df.sample(3)
# Out:
#       Age  Attrition BusinessTravel  DailyRate              Department  \
# 224    31      False     Non-Travel        979  Research & Development
# 18     53      False  Travel Rarely       1219                   Sales
# 1265   33      False     Non-Travel        775  Research & Development
#
#       DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 224                  1          4           Medical                        3
# 18                   2          4     Life Sciences                        1
# 1265                 4          3  Technical Degree                        4
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 224     Male  ...                  3                         4
# 18    Female  ...                  3                         3
# 1265    Male  ...                  3                         4
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 224                  1                 6                      2
# 18                   0                31                      3
# 1265                 2                11                      2
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 224                3               5                   4
# 18                 3              25                   8
# 1265               2               9                   8
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 224                         1                     4
# 18                          3                     7
# 1265                        1                     7
#
# [3 rows x 31 columns]
