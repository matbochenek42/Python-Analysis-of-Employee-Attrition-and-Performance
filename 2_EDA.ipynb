# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## INTRO
#
# The goal of this file is to

# %%
# CHANGE USER_PATH

from pathlib import Path


USER_PATH = Path(r"C:\Users\Mateusz\Desktop\ZBIORCZE\TECH\ANALIZA DANYCH\Python\Projekty MB") 


df_path = USER_PATH / "Python Analysis of Employee Attrition and Performance" / "dataframe.csv"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv(df_path)

# %%
sns.set_theme(style='ticks')

# %%
dict_column = {
    'Attrition': 'How Many Employees Were Fired?',
    'OverTime': 'How Many Employees Work Over Time?'
}

fig, ax = plt.subplots(1, 2)
fig.set_size_inches((10, 5))

for i, (column, title) in enumerate(dict_column.items()):
    ax[i].pie(df[column].value_counts(), labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
    ax[i].set_title(title)

plt.suptitle('Attrition and Over Time Work Comparsion', fontsize=16)
plt.show()

# %%
df.sample(3)
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 1045   40      False      Travel Rarely        896  Research & Development
# 796    25       True      Travel Rarely       1219  Research & Development
# 818    31      False  Travel Frequently        793                   Sales
#
#       DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 1045                 2          3           Medical                        3
# 796                  4          1  Technical Degree                        4
# 818                 20          3     Life Sciences                        3
#
#      Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 1045   Male  ...                  3                         3
# 796    Male  ...                  3                         2
# 818    Male  ...                  3                         1
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 1045                 1                 8                      3
# 796                  1                 7                      3
# 818                  1                 3                      4
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 1045               4               3                   1
# 796                4               7                   7
# 818                3               2                   2
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 1045                        1                     2
# 796                         5                     6
# 818                         2                     2
#
# [3 rows x 31 columns]
