# %% [markdown]
# # DATA CLEANING AND OVERVIEW

# %% [markdown]
# ## INTRO
#
# The goal of this file is to download the dataset, clean it, and save it for further analysis.

# %% [markdown]
# ## IMPORTING DATA FROM KAGGLE

# %% [markdown]
# Data Source: https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset

# %%
# CHANGE USER_PATH

from pathlib import Path


USER_PATH = Path(r"C:\Users\Mateusz\Desktop\ZBIORCZE\TECH\ANALIZA DANYCH\Python\Projekty MB") 


df_path = USER_PATH / "Python Analysis of Employee Attrition & Performance" / "dataframe.csv"

# %%
import kagglehub
import pandas as pd
import os

path = kagglehub.dataset_download("pavansubhasht/ibm-hr-analytics-attrition-dataset")

print("Path to dataset files:", path) 

csv_path = os.path.join(path, "WA_Fn-UseC_-HR-Employee-Attrition.csv")
df = pd.read_csv(csv_path)

df.sample(5) # 5 random rows
# Out:
# Path to dataset files: C:\Users\Mateusz\.cache\kagglehub\datasets\pavansubhasht\ibm-hr-analytics-attrition-dataset\versions\1
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1286   40        No      Travel_Rarely        616  Research & Development
# 167    30        No      Travel_Rarely       1339                   Sales
# 1349   26        No      Travel_Rarely        482  Research & Development
# 401    56        No  Travel_Frequently        906                   Sales
# 173    30        No         Non-Travel        111  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1286                 2          2  Life Sciences              1
# 167                  5          3  Life Sciences              1
# 1349                 1          2  Life Sciences              1
# 401                  6          3  Life Sciences              1
# 173                  9          3        Medical              1
#
# ...

# %% [markdown]
# ## INSPECTING DATA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# ### Duplicates removel (not needed though)

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### Index set up

# %%
df.set_index("EmployeeNumber", inplace=True)

# %% [markdown]
# ### Using function to change the datatype to boolean

# %%
def boolean(row, column_name):
    if row[column_name] == "No":
        return False
    else:
        return True

df["Attrition"] = df.apply(lambda row: boolean(row, "Attrition"), axis=1)
df["OverTime"]  = df.apply(lambda row: boolean(row, "OverTime"), axis=1)

# %% [markdown]
# ### Values replacement within row

# %%
df.BusinessTravel.unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
df["BusinessTravel"] = df["BusinessTravel"].str.replace("_", " ", regex=False)

# %% [markdown]
# ### Dropping unnecessary column (same values in each rows)

# %%
df.drop(labels = ["EmployeeCount", "Over18", "StandardHours"], axis=1, inplace=True)

# %% [markdown]
# ### Final data after cleaning

# %%
df.sample(5)
# Out:
#                 Age  Attrition BusinessTravel  DailyRate  \
# EmployeeNumber
# 1876             30       True  Travel Rarely        945
# 474              37      False  Travel Rarely       1319
# 1238             33      False  Travel Rarely        117
# 350              25      False  Travel Rarely        685
# 783              45      False  Travel Rarely        954
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1876                             Sales                 9          3
# 474             Research & Development                 6          3
# 1238            Research & Development                 9          3
# 350             Research & Development                 1          3
# 783                              Sales                 2          2
#
#                   EducationField  EnvironmentSatisfaction  Gender  ...  \
# EmployeeNumber                                                     ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1470 entries, 1 to 2068
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   bool
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %%
# saving dataframe

df.to_csv(df_path, index=False, encoding='utf-8')
